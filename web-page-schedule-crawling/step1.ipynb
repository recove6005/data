# %%
# pip install bueatifusoap4
# pip install pandas
# pip install openpyxl

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get("https://startcoding.pythonanywhere.com/basic")
html = response.text
soup = BeautifulSoup(html, 'html.parser')

# %%
soup.select_one(".product-category").text
# Out:
# '노트북'

# %%
soup.select_one(".product-name > a").attrs
# Out:
# {'href': '#product1_detail.html'}

# %%
soup.select_one(".product-name > a").attrs['href']
# Out:
# '#product1_detail.html'

# %%
soup.select_one(".product-price").text
# soup.select_one(".product-price").text.strip()
# soup.select_one(".product-price").text.strip().replace(',','').replace('원', '')
# Out:
# '1,419,000원\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t'

# %%
items = soup.select(".product-body")
for item in items:
    category = item.select_one(".product-category").text
    name = item.select_one(".product-name").text
    link = item.select_one(".product-name > a").attrs['href']
    price = item.select_one(".product-price").text.strip().replace(',','')
    print(category, name, link, price)
# Out:
# 노트북 에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB, WIN11 Home, SFG16-71-77FT #product1_detail.html 1419000원
# 노트북 삼성전자 노트북 플러스2 15.6, 퓨어 화이트, NT550XDA-K24AT, 펜티엄, 256GB, 8GB, WIN11 Pro #product2_detail.html 549000원
# 노트북 레노버 아이디어패드 슬림 1 15AMN7 15.6, 256GB, Free DOS, 82VG002EKR, 라이젠3, Cloud Grey (82VG), 8GB #product3_detail.html 529000원
# 노트북 레노버 V15 G4 AMN 15.6, Arctic Grey, 라이젠3, 256GB, 8GB, WIN11 Home, 82YU0009KR #product4_detail.html 624000원
#
# 										649000
# 노트북 LG 울트라PC 엣지 16, 차콜 그레이, 라이젠5, 256GB, 16GB, WIN11 Home, 16U70R-GA56K #product5_detail.html 1135000원
# 노트북 베이직스 베이직북 14 3세대, BB1422SS, 256GB, White, WIN11 Pro, 셀러론, 8GB #product6_detail.html 398000원
# 노트북 레노버 아이디어패드 슬림 5i 14IRL 14, Cloud Grey, 코어i5, 512GB, 16GB, Free DOS, 82XD002XKR #product7_detail.html 899000원
#
# 										1099000
# 노트북 레노버 아이디어패드 슬림 5 16IRL 16, Cloud Grey, 512GB, 16GB, Free DOS, 82XF001RKR #product8_detail.html 929000원
# ...

# %%
# for in range 반복문
for i in range(1, 5):
    print(i)

# f스트링
name = "피카츄"
age = 3
greeting = f"안녕하세요, 제 이름은 {name}입니다. 나이는 {age}입니다."

print(greeting)
# Out:
# 1
# 2
# 3
# 4
# 안녕하세요, 제 이름은 피카츄입니다. 나이는 3입니다.

# %%
# 여러 개의 페이지에서 크롤링하기 : URL 조작

for i in range(1, 5):
    response = requests.get("https://startcoding.pythonanywhere.com/basic?=page{i}")
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    items = soup.select(".product")
    for item in items:
        category = item.select_one(".product-category").text
        name = item.select_one(".product-name").text
        link = item.select_one(".product-name > a").attrs['href']
        price = item.select_one(".product-price").text.split('원')[0].replace(',','')
        print(category, name, link, price)
# Out:
# 노트북 에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB, WIN11 Home, SFG16-71-77FT #product1_detail.html 1419000
# 노트북 삼성전자 노트북 플러스2 15.6, 퓨어 화이트, NT550XDA-K24AT, 펜티엄, 256GB, 8GB, WIN11 Pro #product2_detail.html 549000
# 노트북 레노버 아이디어패드 슬림 1 15AMN7 15.6, 256GB, Free DOS, 82VG002EKR, 라이젠3, Cloud Grey (82VG), 8GB #product3_detail.html 529000
# 노트북 레노버 V15 G4 AMN 15.6, Arctic Grey, 라이젠3, 256GB, 8GB, WIN11 Home, 82YU0009KR #product4_detail.html 624000
# 노트북 LG 울트라PC 엣지 16, 차콜 그레이, 라이젠5, 256GB, 16GB, WIN11 Home, 16U70R-GA56K #product5_detail.html 1135000
# 노트북 베이직스 베이직북 14 3세대, BB1422SS, 256GB, White, WIN11 Pro, 셀러론, 8GB #product6_detail.html 398000
# 노트북 레노버 아이디어패드 슬림 5i 14IRL 14, Cloud Grey, 코어i5, 512GB, 16GB, Free DOS, 82XD002XKR #product7_detail.html 899000
# 노트북 레노버 아이디어패드 슬림 5 16IRL 16, Cloud Grey, 512GB, 16GB, Free DOS, 82XF001RKR #product8_detail.html 929000
# 노트북 에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i5, 512GB, 16GB, Free DOS, SFG16-71-51BY #product9_detail.html 1008000
# ...

# %%
# 크롤링한 데이터 엑셀에 저장하기
import pandas as pd

data = []

for i in range(1, 5):
    response = requests.get("https://startcoding.pythonanywhere.com/basic?=page{i}")
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    items = soup.select(".product")
    for item in items:
        category = item.select_one(".product-category").text
        name = item.select_one(".product-name").text
        link = item.select_one(".product-name > a").attrs['href']
        price = item.select_one(".product-price").text.split('원')[0].replace(',','')
        print(category, name, link, price)
        data.append([category, name, link, price])
# Out:
# 노트북 에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB, WIN11 Home, SFG16-71-77FT #product1_detail.html 1419000
# 노트북 삼성전자 노트북 플러스2 15.6, 퓨어 화이트, NT550XDA-K24AT, 펜티엄, 256GB, 8GB, WIN11 Pro #product2_detail.html 549000
# 노트북 레노버 아이디어패드 슬림 1 15AMN7 15.6, 256GB, Free DOS, 82VG002EKR, 라이젠3, Cloud Grey (82VG), 8GB #product3_detail.html 529000
# 노트북 레노버 V15 G4 AMN 15.6, Arctic Grey, 라이젠3, 256GB, 8GB, WIN11 Home, 82YU0009KR #product4_detail.html 624000
# 노트북 LG 울트라PC 엣지 16, 차콜 그레이, 라이젠5, 256GB, 16GB, WIN11 Home, 16U70R-GA56K #product5_detail.html 1135000
# 노트북 베이직스 베이직북 14 3세대, BB1422SS, 256GB, White, WIN11 Pro, 셀러론, 8GB #product6_detail.html 398000
# 노트북 레노버 아이디어패드 슬림 5i 14IRL 14, Cloud Grey, 코어i5, 512GB, 16GB, Free DOS, 82XD002XKR #product7_detail.html 899000
# 노트북 레노버 아이디어패드 슬림 5 16IRL 16, Cloud Grey, 512GB, 16GB, Free DOS, 82XF001RKR #product8_detail.html 929000
# 노트북 에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i5, 512GB, 16GB, Free DOS, SFG16-71-51BY #product9_detail.html 1008000
# ...

# %%
# 데이터프레임 만들기
df = pd.DataFrame(data, columns=['카테고리', '상품명', '링크', '가격'])
df
# Out:
#    카테고리                                                상품명  \
# 0   노트북  에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB...
# 1   노트북  삼성전자 노트북 플러스2 15.6, 퓨어 화이트, NT550XDA-K24AT, 펜티...
# 2   노트북  레노버 아이디어패드 슬림 1 15AMN7 15.6, 256GB, Free DOS, ...
# 3   노트북  레노버 V15 G4 AMN 15.6, Arctic Grey, 라이젠3, 256GB,...
# 4   노트북  LG 울트라PC 엣지 16, 차콜 그레이, 라이젠5, 256GB, 16GB, WIN...
# 5   노트북  베이직스 베이직북 14 3세대, BB1422SS, 256GB, White, WIN1...
# 6   노트북  레노버 아이디어패드 슬림 5i 14IRL 14, Cloud Grey, 코어i5, 5...
# 7   노트북  레노버 아이디어패드 슬림 5 16IRL 16, Cloud Grey, 512GB, 1...
# 8   노트북  에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i5, 512GB, 16GB...
# 9   노트북  삼성전자 갤럭시북 2 15.6, 500GB, 실버, NT550XED-K78AS, 코...
# 10  노트북  에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB...
# 11  노트북  삼성전자 노트북 플러스2 15.6, 퓨어 화이트, NT550XDA-K24AT, 펜티...
# 12  노트북  레노버 아이디어패드 슬림 1 15AMN7 15.6, 256GB, Free DOS, ...
# 13  노트북  레노버 V15 G4 AMN 15.6, Arctic Grey, 라이젠3, 256GB,...
# 14  노트북  LG 울트라PC 엣지 16, 차콜 그레이, 라이젠5, 256GB, 16GB, WIN...
# ...

# %%
# 생성한 데이터 프레임을 엑셀에 저장하기
# index=False : 엑셀 번호 생성 안 되게끔
df.to_excel('result.xlsx', index=False)

# %%
# 동적 페이지의 경우 => 셀레니움 라이브러리 사용
